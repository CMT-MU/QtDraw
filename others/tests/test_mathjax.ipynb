# %%
import sys
from PySide6.QtWidgets import QApplication
from others.tests.test_mathjax import MainWindow
from IPython import get_ipython

ipython = get_ipython()
if ipython is not None:
    ipython.enable_gui('qt6')

app = QApplication.instance() or QApplication(sys.argv)
win = MainWindow()
win.show()

# %%
win.svg.setText(r"\int_{-\infty}^\infty dx |\psi(x)|^2=1")
